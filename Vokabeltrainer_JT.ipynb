# %%
from datetime import date    # fuer den Zeitstempel

# Definition einer Vokabel
# Wir müssen diese Wörte lernen 
word_1 ={
    'english_word':'chair',          # Der zu übersetzende englische Begriff
    'german_choose_word':['Tisch','Stuhl','Sessel'],    # Liste der möglichen Antworten
    'answer_index':2,               # Nummer der richtigen Antwort in Listenelement
    'is_learned':False,          # Wurde richtig geantwortet TRUE / FALSE
    'trained_at':'',            # datetime.datetime(2021, 1, 27), todo ??? Type Datum und Zeit der Beantwortung
    }

word_2 ={
    'english_word':'window',          
    'german_choose_word':['Fenster','Tuer','Treppe'],
    'answer_index':1,               
    'is_learned':False,          
    'trained_at':'',                
    }

word_3 ={
    'english_word':'fridge',          
    'german_choose_word':['Staubsauger','Spuelmaschine','Kuehlschrank'],
    'answer_index':3,               
    'is_learned':False,          
    'trained_at':'', 
    }

# Das ist mein Vokabulary zu lernen
vokabulary = [word_1, word_2, word_3]     # Eine Liste aus mehreren Dictionaries 

# Hier werden die antworten noch vorgegeben, da wir noch kein 'User-Input' kennen
#answer_in =(2,2,1)                           # Antwort auf die  (richtige Antwort)


zaehler =0          # Schleifenvariable für die Indizes

#for vok in vokabulary[:1]:
for vok in vokabulary:
    print('\x1bc') # Terminal löschen
    print('Wie lautet das deutsche Wort für',vok['english_word'],'?')        # Die Frage wird ausgegeben
    print(f'Antwortmoeglichkeiten:\t\t1. {vok["german_choose_word"][0]}\n\t\t\t\t2. {vok["german_choose_word"][1]}\n\t\t\t\t3. {vok["german_choose_word"][2]}\n')
    
    
    answer_in=int(input("Bitte die Nr. der richtigen Lösung eingeben"))
    print('Antwort des Schuelers:',answer_in,'\n')
        
    if answer_in == vok['answer_index']:
        print('Prima, das war die richtige Antwort!')
        # Is learned auf TRUE setzen
        vok['is_learned']=True
    else:
        print('Das war leider eine falsche Antwort.')
        # Is learned auf FALSE setzen
        vok['is_learned']=False
        answer=vok['answer_index']
        # ausgabe der richtigen (hier vorgegebenen) Antwort
        print('Richtig waere die Antwort',vok["answer_index"],vok["german_choose_word"][answer-1],'gewesen.')
    print('--------------------------------------------------------------\n')
    
    # Speichern des Timestamps der Antwort
    tag=date.today()
    vok['trained_at']=tag
        #print(vok['trained_at'])
    # Abfrage nächste Vokabel
    # Zaehler um 1 erhoehen
    zaehler += 1

  
vokabulary
# Ausbaustufen:
# Sortieren der richtigen Antworten nach Timestamp absteigend, damit die ältesten als erste wiederholt werden: 
# Sortieren der falschen Antworten nach Timestamp absteigend, damit die ältesten als erste wiederholt werden: 
 # Auswertung - Anzahl von richtig, Anzahl von falsch 
# Gruppenweise Sortierung (falsch, richtig), damit sowohl bereits richtige und falsche abgefragt werden können
# Wir brauchen keine Timestamp  
# Zeigen,
# Out:
# c
# Wie lautet das deutsche Wort für chair ?
# Antwortmoeglichkeiten:		1. Tisch
# 				2. Stuhl
# 				3. Sessel
#
# Antwort des Schuelers: 1
#
# Das war leider eine falsche Antwort.
# Richtig waere die Antwort 2 Stuhl gewesen.
# --------------------------------------------------------------
#
# c
# Wie lautet das deutsche Wort für window ?
# Antwortmoeglichkeiten:		1. Fenster
# 				2. Tuer
# 				3. Treppe
#
# Antwort des Schuelers: 1
#
# Prima, das war die richtige Antwort!
# --------------------------------------------------------------
#
# c
# Wie lautet das deutsche Wort für fridge ?
# Antwortmoeglichkeiten:		1. Staubsauger
# 				2. Spuelmaschine
# 				3. Kuehlschrank
#
# Antwort des Schuelers: 3
#
# Prima, das war die richtige Antwort!
# --------------------------------------------------------------
# [{'english_word': 'chair',
#   'german_choose_word': ['Tisch', 'Stuhl', 'Sessel'],
#   'answer_index': 2,
#   'is_learned': False,
#   'trained_at': datetime.date(2021, 1, 27)},
#  {'english_word': 'window',
#   'german_choose_word': ['Fenster', 'Tuer', 'Treppe'],
#   'answer_index': 1,
#   'is_learned': True,
#   'trained_at': datetime.date(2021, 1, 27)},
#  {'english_word': 'fridge',
#   'german_choose_word': ['Staubsauger', 'Spuelmaschine', 'Kuehlschrank'],
#   'answer_index': 3,
#   'is_learned': True,
#   'trained_at': datetime.date(2021, 1, 27)}]
